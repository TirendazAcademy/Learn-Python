# %%
import math

math.sqrt(16)
# Out:
# 4.0

# %%
math.factorial(5)
# Out:
# 120

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import random

random.randint(1,10)
# Out:
# 10

# %%
random.randint(1,10)
# Out:
# 2

# %%
random.random()
# Out:
# 0.3528053333470047

# %%
random.random()
# Out:
# 0.7210911498863867

# %%
import datetime 

bugun = datetime.date.today()

print("Bugünün tarihi: ", bugun)
# Out:
# Bugünün tarihi:  2025-08-03

# %%
simdi = datetime.datetime.now()

print("Şu an: ", simdi)
# Out:
# Şu an:  2025-08-03 10:25:26.060811

# %% [raw]
# proje/
#     geometri/
#         __init__.py
#         daire.py
#         dikdortgen.py

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
arr*2
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
import pandas as pd

# %%
data = {
    "isim": ["Ali", "Ayşe", "Mehmet"],
    "yas": [25, 30, 22]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#      isim  yas
# 0     Ali   25
# 1    Ayşe   30
# 2  Mehmet   22

# %%
df["isim"]
# Out:
# 0       Ali
# 1      Ayşe
# 2    Mehmet
# Name: isim, dtype: object

# %%
print(df.describe())
# Out:
#              yas
# count   3.000000
# mean   25.666667
# std     4.041452
# min    22.000000
# 25%    23.500000
# 50%    25.000000
# 75%    27.500000
# max    30.000000
